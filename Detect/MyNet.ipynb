# %% [markdown]
# # Импорты

# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2

# %% [markdown]
# # Загрузка модели

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5s', pretrained=True)
# Out:
# Using cache found in C:\Users\emely/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-4-23 Python-3.10.0 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
# requirements: C:\Users\emely\.cache\torch\hub\requirements.txt not found, check failed.
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %% [markdown]
# # Обучение

# %%
# !cd yolov5 && python train.py --img 320 --batch 16 --epochs 15 --data data.yaml --weights yolov5s.pt --workers 2
# Out:
# github: skipping check (not a git repository), for updates see https://github.com/ultralytics/yolov5
# requirements: D:\leason\Artificial_intelligence\Detect\requirements.txt not found, check failed.
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=15, batch_size=16, imgsz=320, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5  2023-4-23 Python-3.10.0 torch-1.13.1+cu117 CUDA:0 (NVIDIA GeForce RTX 3060, 12287MiB)
#
# ...

# %%
# !cd yolov5 && python val.py --img 320 --batch 16 --epochs 15 --data data.yaml --weights yolov5s.pt
